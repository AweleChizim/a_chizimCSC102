# %%
#Project 1
#import pandas and read file
import pandas as cp


def employee_check(usersn):
    ''' Return dg if strings usersn and userfn 
    are elements of the same row in table dg '''
    
    employee_data = cp.read_csv("jt-ventures.csv")
    dg = cp.DataFrame(employee_data)
    columns = list(dg)
    
    for i in range(len(dg)):
        for i in columns:
            if(usersn == dg[i][1]):
                print(f"Welcome {usersn}! You've been granted access to the company profile")
            else:
                print("Apologies")
            
#     for i in columns:
#         if usersn != dg[i][0]: 
#             print ("Apologies! You do not have access to the company profile")

# def department_list():
#     for i in range(len(dg)):
#         for i in columns:
#             if dept == "Logistics":
#                 if dept == dg[i][0]:
#                     return dg[i][0]
#     return dg[i][0]
# usersn = input("Enter Surname: ")
usersn = input("Enter Surname: ")
# dept = input("Enter Department: ")
employee_check(usersn)
# department_list()
# Out:
# Enter Surname: EBI
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#project 2
location = int(input("Welcome To Yega Services! \nWhere would you like your package delivered to? \nEnter 1 for Ibeju-Lekki or 2 for Epe:"))
weight = int(input("How much does the package weigh(in Kg)?"))

def ibeju_delivery(weight):
    '''(int) -> str
    
    Determines price depending on weight for deliveries in ibeju-lekki
    >>> ibeju_delivery(weight)
    Delivery Price is N2000
    '''
    if weight >= 10:
        price = 2000
    else:
        price = 1500
    return print(f'Delivery Price is N{price}')

def epe_delivery(weight):
    '''(int) -> str
    
    Determines price depending on weight for deliveries in epe
    >>> epe_delivery(10)
    Delivery Price is N5000
    '''
    
    if weight >= 10:
        price = 5000
    else:
        price = 4000
        return print(f'Delivery Price is N{price}')

price = 0
if location == 1:
    ibeju_delivery(weight)
elif location == 2:
    epe_delivery(weight)
# Out:
# Welcome To Yega Services!
# Where would you like your package delivered to?
# Enter 1 for Ibeju-Lekki or 2 for Epe:2
# How much does the package weigh(in Kg)?12

# %%
#project 3
#import pandas
import pandas as pd

name = input("Name:")
age = input("Age:")
department = int(input("Enter 1 for Computer Science or 2 for Mass Communication:"))


def csc_check():
    jamb_score = int(input("JAMB Score:"))
    print("KEY:\nEnter 1 for A1 \n      2 for B2&3\n      3 for C4-6\n      4 for D7\n      5 for E8\n      6 for F9")
    math = int(input("MATH:"))
    eng = int(input("ENGLISH:"))
    phy = int(input("PHYSICS:"))
    chem = int(input("CHEMISTRY:"))
    fmath = int(input("FURTHER MATH:"))
    interview = int(input("INTERVIEW - Enter 1 for PASS or 2 for FAIL:"))

    if (jamb_score >= 230) and (interview == 1) and (math >= 1 and math <= 3) and (eng >= 1 and eng <= 3) and (phy >= 1 and phy <= 3) and (chem >= 1 and chem <= 3) and (fmath >= 1 and fmath <= 3):
        status = "ADMITTED"
        data = {'Name': [name], 'Department': ["Computer Science"], 'Age': [age]}
        ad = pd.DataFrame(data)
        ad.to_csv('admitted.csv')
    else:
        status = "NOT ADMITTED"
        data = {'Name': [name], 'Department': ["Computer Science"], 'Age': [age]}
        ad = pd.DataFrame(data)
        ad.to_csv('not-admitted.csv')
    return print(f'{status}')

def masscom_check():
    jamb_score = int(input("JAMB Score:"))
    print("KEY:\nEnter 1 for A1 \n      2 for B2&3\n      3 for C4-6\n      4 for D7\n      5 for E8\n      6 for F9")
    math = int(input("MATH:"))
    eng = int(input("ENGLISH:"))
    crs = int(input("CRS:"))
    lit = int(input("LITERATURE:"))
    gov = int(input("GOVERNMENT:"))
    interview = int(input("INTERVIEW - Enter 1 for PASS or 2 for FAIL:"))

    if (jamb_score >= 220) and (interview == 1) and (math >= 1 and math <= 3) and (eng >= 1 and eng <= 3) and (crs >= 1 and crs <= 3) and (lit >= 1 and lit <= 3) and (gov >= 1 and gov <= 3):
        status = "ADMITTED"
        data = {'Name': [name], 'Department': ["Mass Communication"], 'Age': [age]}
        ad = pd.DataFrame(data)
        ad.to_csv('admitted.csv')
    else:
        status = "NOT ADMITTED"
        data = {'Name': [name], 'Department': ["Mass Communication"], 'Age': [age]}
        ad = pd.DataFrame(data)
        ad.to_csv('not-admitted.csv')
    return print(f'{status}')

if department == 1:
    csc_check()
elif department == 2:
    masscom_check()
# Out:
# Name:John Doe
# Age:17
# Enter 1 for Computer Science or 2 for Mass Communication:1
# JAMB Score:278
# KEY:
# Enter 1 for A1
#       2 for B2&3
#       3 for C4-6
#       4 for D7
#       5 for E8
#       6 for F9
# MATH:1
# ENGLISH:1
# PHYSICS:1
# CHEMISTRY:1
# FURTHER MATH:1
# Enter 1 for PASS or 2 for Fail:1
# ADMITTED
